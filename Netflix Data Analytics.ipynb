# %%
# Importing the dataset
import pandas as pd
data = pd.read_csv(r"C:\Users\Admin\Desktop\SQL\portfolio\NetFlix datasets.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7667   s7783    Movie                                     Zozo
# 7668   s7784    Movie                                   Zubaan
# 7669   s7785    Movie                        Zulu Man in Japan
# 7670   s7786  TV Show                    Zumbo's Just Desserts
# 7671   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head()                  #will shows the top 5 records of the Netflix Dataset
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.tail()    #shows the bottom 5 records
# Out:
#      Show_Id Category                                    Title     Director  \
# 7667   s7783    Movie                                     Zozo  Josef Fares
# 7668   s7784    Movie                                   Zubaan  Mozez Singh
# 7669   s7785    Movie                        Zulu Man in Japan          NaN
# 7670   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7671   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7667  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7668  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7669                                            Nasty C
# 7670                         Adriano Zumbo, Rachel Khoo
# 7671                                                NaN
#
#                                                 Country Release_Date Rating  \
# 7667  Sweden, Czech Republic, United Kingdom, Denmar...    19-Oct-20  TV-MA
# ...

# %%
data.shape          #no of rows and columns
# Out:
# (7672, 11)

# %%
data.size                   #total values(elements) of dataset
# Out:
# 84392

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7672 entries, 0 to 7671
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7672 non-null   object
#  1   Category      7672 non-null   object
#  2   Title         7672 non-null   object
#  3   Director      5370 non-null   object
#  4   Cast          6965 non-null   object
#  5   Country       7171 non-null   object
#  6   Release_Date  7662 non-null   object
#  7   Rating        7665 non-null   object
#  8   Duration      7672 non-null   object
#  9   Type          7672 non-null   object
#  10  Description   7672 non-null   object
# dtypes: object(11)
# memory usage: 659.4+ KB

# %%
data[data.duplicated()]    #two duplicates
# Out:
#      Show_Id Category              Title        Director  \
# 6198    s684    Movie           Backfire     Dave Patten
# 6516   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6198  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6516  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type  \
# 6198     5-Apr-19  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6516     4-Sep-20  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6198  When two would-be robbers accidentally kill a ...
# 6516  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)  #duplicates removed permanently

# %%
data.shape
# Out:
# (7670, 11)

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7667    False     False  False     False  False    False         False
# 7668    False     False  False     False  False    False         False
# 7669    False     False  False      True  False     True         False
# 7670    False     False  False      True  False    False         False
# 7671    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2302
# Cast             707
# Country          501
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data[data['Title'].isin(['House of Cards'])]    #"House of cards and movie director "
# Out:
#      Show_Id Category           Title  \
# 2781   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2781  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2781  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2781     2-Nov-18  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2781  A ruthless politician will stop at nothing to ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12328\1147803333.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date_N'] = pd.to_datetime(data['Release_Date'])

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()    #TV shows & Movies counts the occurrence of all individua Years in Date Column
# Out:
# Date_N
# 2019.0    2129
# 2020.0    2002
# 2018.0    1653
# 2017.0    1196
# 2016.0     430
# 2021.0     117
# 2015.0      79
# 2014.0      23
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')    #Bar Graph
# Out:
# <Axes: xlabel='Date_N'>

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby('Category').Category.count()      #Movies & TV shows in the dataset shown with Bar graph To group all unique items of a colum and show their count
# Out:
# Category
# Movie      5350
# TV Show    2320
# Name: Category, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Category', data=data)
plt.show()

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data['Year'] = data['Date_N'].dt.year     #New column

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[ (data['Category'] =='Movie') & (data['Year']==2000)]            #Filtering movies released in year 2000
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
data[ (data['Category'] =='Movie') & (data['Year']==2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7645   s7761    Movie                                Zaki Chan
# 7666   s7782    Movie                                     Zoom
# 7667   s7783    Movie                                     Zozo
# 7669   s7785    Movie                        Zulu Man in Japan
# 7671   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[ (data['Category']=='TV Show') & (data['Country']== 'India') ]  #Shows only thr titles of all TV shows in India Only
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 337     s341  TV Show                        Agent Raghav          NaN
# 361     s365  TV Show                        Akbar Birbal          NaN
# 530     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6149   s6249  TV Show                The Creative Indians          NaN
# 6296   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6365   s6468  TV Show              The House That Made Me          NaN
# 7180   s7293  TV Show                          Typewriter          NaN
# 7588   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country Release_Date  \
# ...

# %%
data[ (data['Category']=='TV Show') & (data['Country']== 'India') ] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 337                           Agent Raghav
# 361                           Akbar Birbal
# 530                    Anjaan: Rural Myths
#                        ...
# 6149                  The Creative Indians
# 6296    The Golden Years with Javed Akhtar
# 6365                The House That Made Me
# 7180                            Typewriter
# 7588                       Yeh Meri Family
# Name: Title, Length: 69, dtype: object

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data['Director'].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
#                           ..
# Jason Krawczyk             1
# Quinn Lasher               1
# Elle Callahan              1
# Ana Kokkinos               1
# Sam Dunn                   1
# Name: count, Length: 4030, dtype: int64

# %%
data['Director'].value_counts().head()   Top 5 Directors with highest number of TV shows & Movies on Netflix
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Name: count, dtype: int64

# %%
data['Director'].value_counts().head(10)  # Top 10 Directors with highest number of TV shows & Movies on Netflix
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: count, dtype: int64

# %%
     #Show all records where category is movie and type is comedies or country is United Kingdom, filtering with AND, OR operators

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies')]    #AND
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7227   s7340    Movie         Undercover Brother 2            Leslie Small
# 7474   s7589    Movie            Where's the Money         Scott Zabielski
# 7507   s7622    Movie                    Wild Oats            Andy Tennant
# 7518   s7633    Movie                 Wine Country             Amy Poehler
# 7547   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies') | (data['Country']=='United Kingdom')]   #)OR
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7553   s7669  TV Show  World War II in Colour               NaN
# 7554   s7670  TV Show  World's Busiest Cities               NaN
# 7571   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7608   s7724    Movie            You Can Tutu       James Brown
# 7623   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
#Movies/SHows Tom Cruise (cast)

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data[data['Cast']=='Tom Cruise']   #filtering
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
data_new = data.dropna()     #drops rows that contains missing values

# %%
data_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]    #cast in two movies
# Out:
#      Show_Id Category     Title              Director  \
# 3798   s3861    Movie  Magnolia  Paul Thomas Anderson
# 4987   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3798  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 4987  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3798     1-Jan-20      R  189 min  Dramas, Independent Movies
# 4987     1-Jul-19      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3798  Through chance, human action, past history and... 2020-01-01  2020.0
# 4987  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
#different ratings defined by Netflix

# %%
data.Rating.nunique()
# Out:
# 14

# %%
data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#How many movies got the 'TV-14' rating in Canada

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['Category']=='Movie') & (data['Rating'] == 'TV-14')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                     1-Oct      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7648   s7764    Movie                     Zenda      Avadhoot Gupte
# 7649   s7765    Movie                      Zero          Aanand Rai
# 7653   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7654   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7668   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
data[(data['Category']=='Movie') & (data['Rating'] == 'TV-14') & (data['Country']=='Canada')].shape
# Out:
# (11, 13)

# %%
data[(data['Category']=='Movie') & (data['Rating'] == 'TV-14') & (data['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 605     s609    Movie                               At First Light
# 1482   s1507    Movie                   Counterfeiting in Suburbia
# 3655   s3714    Movie                            Long Time Running
# 3892   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5249   s5336    Movie                   Sadie's Last Days on Earth
# 5306   s5393    Movie                                   Sardaar ji
# 5967   s6062    Movie                  The Accountant of Auschwitz
# 6911   s7024    Movie                         The Wrong Babysitter
# 6927   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
 #How many TV Shows got the 'R' rating after year 2018

# %%
data[(data['Category']=='TV Show') & (data['Rating'] == 'R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4426   s4498  TV Show                                Nobel                NaN
# 6333   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 4426  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway    10-Dec-16
# 6333  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration                                             Type  \
# 4426      R  1 Season  International TV Shows, TV Dramas, TV Thrillers
# 6333      R  1 Season                                         TV Shows
#
#                                             Description     Date_N    Year
# 4426  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6333  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
data[(data['Category']=='TV Show') & (data['Rating'] == 'R') & (data['Year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6333   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6333  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration      Type  \
# 6333      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6333  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
#What is the maximum duration of a Movie/Show on Netflix

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data[['Minutes','Unit']] = data['Duration'].str.split(' ', expand=True)  #Str.split()

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data.Minutes.max()                               #max()
# Out:
# '99'

# %%
data.Minutes.min()
# Out:
# '1'

# %%
data.Minutes.mean()
# Out:
# inf

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# Year                   float64
# Minutes                 object
# Unit                    object
# dtype: object

# %%
# WHich individual country has the hightest No of TV Shows

# %%
data_tvshow = data[data['Category'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     1-Jul-17
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                669
# United Kingdom                                               192
# Japan                                                        155
# South Korea                                                  143
# India                                                         69
#                                                             ...
# Taiwan, China                                                  1
# Canada, United States, United Kingdom, France, Luxembourg      1
# Chile, Italy                                                   1
# France, Australia, Germany                                     1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 177, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    669
# Name: count, dtype: int64

# %%
#Sorting Dataset by Year

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data.sort_values(by='Year').head(2)
# Out:
#      Show_Id Category                 Title              Director  \
# 7001   s7114    Movie  To and From New York  Sorin Dan Mihalcescu
# 1735   s1766  TV Show       Dinner for Five                   NaN
#
#                                                    Cast        Country  \
# 7001  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1735                                                NaN  United States
#
#      Release_Date Rating  Duration                                   Type  \
# 7001     1-Jan-08  TV-MA    81 min  Dramas, Independent Movies, Thrillers
# 1735     4-Feb-08  TV-MA  1 Season           Stand-Up Comedy & Talk Shows
#
#                                             Description     Date_N    Year  \
# 7001  While covering a story in New York City, a Sea... 2008-01-01  2008.0
# 1735  In each episode, four celebrities join host Jo... 2008-02-04  2008.0
#
#      Minutes    Unit
# 7001      81     min
# 1735       1  Season

# %%
data.sort_values(by='Year', ascending=False).head(10)
# Out:
#      Show_Id Category                                              Title  \
# 4800   s4882    Movie                                  Playing for Keeps
# 6336   s6439  TV Show                              The Haunted Hathaways
# 2702   s2754  TV Show                             History of Swear Words
# 6565   s6671    Movie                       The Minimalists: Less Is Now
# 6530   s6635  TV Show                                      The Magicians
# 2748   s2800    Movie                                               Hook
# 363     s367    Movie                                          Al acecho
# 1334   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 6397   s6501    Movie                                   The Intouchables
# 6375   s6478  TV Show                               The Idhun Chronicles
#
#                             Director  \
# 4800                Gabriele Muccino
# 6336                             NaN
# 2702                             NaN
# ...

# %%
#category is Movie and type is 'Dramas'       or category is TV shows and type is 'Kids TV'

# %%
data [(data['Category']=='Movie') & (data['Type']=='Dramas')].head(2)
# Out:
#   Show_Id Category Title        Director  \
# 4      s5    Movie    21  Robert Luketic
# 7      s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#   Release_Date Rating Duration    Type  \
# 4     1-Jan-20  PG-13  123 min  Dramas
# 7     1-Nov-19      R  119 min  Dramas
#
#                                          Description     Date_N    Year  \
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
# 7  After one of his high school students attacks ... 2019-11-01  2019.0
#
#   Minutes Unit
# 4     123  min
# 7     119  min

# %%
data [(data['Category']=='TV Show') & (data['Type']=="Kids' TV")].head(2)
# Out:
#     Show_Id Category         Title     Director  \
# 111    s112  TV Show       44 Cats          NaN
# 276    s277  TV Show  Abby Hatcher  Kyran Kelly
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#     Release_Date Rating   Duration      Type  \
# 111     1-Oct-20  TV-Y7  2 Seasons  Kids' TV
# 276     1-Jul-20   TV-Y   1 Season  Kids' TV
#
#                                            Description     Date_N    Year  \
# 111  Paw-esome tales abound when singing furry frie... 2020-10-01  2020.0
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-07-01  2020.0
#
#     Minutes     Unit
# 111       2  Seasons
# 276       1   Season

# %%
data [(data['Category']=='Movie') & (data['Type']=='Dramas') | (data['Category']=='TV Show') & (data['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7551   s7667  TV Show               World of Winx  Iginio Straffi
# 7600   s7716  TV Show                        Yoko             NaN
# 7602   s7718  TV Show                         YOM             NaN
# 7641   s7757  TV Show                          Z4             NaN
# 7644   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
